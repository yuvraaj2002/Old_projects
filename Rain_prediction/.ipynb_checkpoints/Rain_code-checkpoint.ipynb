# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Loading the csv file
df = pd.read_csv('weatherAUS.csv')

# %% [markdown]
# # Exploratory data analysis

# %%
# Let's check the shape of the dataframe
df.shape
# Out:
# (145460, 23)

# %%
# Let's see first 5 rows of the dataframe
df.head(5)
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
# Let's check the data type of all the features in the dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %%
# Let's reduce the memory usage by using appropriate data types
float_cols = df.select_dtypes(include=np.float64)
df[float_cols.columns] = df[float_cols.columns].astype(np.float32)

# %%
# Let's get some decriptive statistical information about the data 
df.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194036      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200001       0.800000      7.400000
# max        33.900002      48.099998     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035229      14.043426      18.662657
# std        3.785483      13.607062       8.915376       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
# Let's check are there any null values
df.isnull().mean()*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %%
# Let's check any duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
ex = [0,0.2]
df['RainTomorrow'].value_counts().plot(kind='pie',autopct='%.2f',explode=ex)
# Out:
# <AxesSubplot:ylabel='RainTomorrow'>

# %%
print(len(df['Location'].unique()))
df['Location'].unique()
# Out:
# 49
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
# Lets check the distribution of all the above features so that we could decide whether use IQR method of z-score method for outliers
fig,ax = plt.subplots(4,4,figsize=(18,14))

sns.kdeplot(df['MinTemp'],shade=True,ax = ax[0][0],color = 'green')
ax[0][0].axvline(df['MinTemp'].mean(), color='red', label='mean')
ax[0][0].axvline(df['MinTemp'].median(), color='green', label='median')
ax[0][0].axvline(df['MinTemp'].mode()[0], color='blue', label='mode')
ax[0][0].legend()

sns.kdeplot(df['MaxTemp'],shade=True,ax = ax[0][1],color = 'green')
ax[0][1].axvline(df['MaxTemp'].mean(), color='red', label='mean')
ax[0][1].axvline(df['MaxTemp'].median(), color='green', label='median')
ax[0][1].axvline(df['MaxTemp'].mode()[0], color='blue', label='mode')
ax[0][1].legend()

sns.kdeplot(df['Rainfall'],shade=True,ax = ax[0][2],color = 'green')
ax[0][2].axvline(df['Rainfall'].mean(), color='red', label='mean')
ax[0][2].axvline(df['Rainfall'].median(), color='green', label='median')
ax[0][2].axvline(df['Rainfall'].mode()[0], color='blue', label='mode')
ax[0][2].legend()

sns.kdeplot(df['WindSpeed9am'],shade=True,ax = ax[0][3],color = 'green')
ax[0][3].axvline(df['WindSpeed9am'].mean(), color='red', label='mean')
ax[0][3].axvline(df['WindSpeed9am'].median(), color='green', label='median')
ax[0][3].axvline(df['WindSpeed9am'].mode()[0], color='blue', label='mode')
ax[0][3].legend()


sns.kdeplot(temp1['WindSpeed3pm'],shade=True,ax = ax[1][0],color = 'green')
ax[1][0].axvline(temp1['WindSpeed3pm'].mean(), color='red', label='mean')
ax[1][0].axvline(temp1['WindSpeed3pm'].median(), color='green', label='median')
ax[1][0].axvline(temp1['WindSpeed3pm'].mode()[0], color='blue', label='mode')
ax[1][0].legend()

sns.kdeplot(df['Humidity9am'],shade=True,ax = ax[1][1],color = 'green')
ax[1][1].axvline(df['Humidity9am'].mean(), color='red', label='mean')
ax[1][1].axvline(df['Humidity9am'].median(), color='green', label='median')
ax[1][1].axvline(df['Humidity9am'].mode()[0], color='blue', label='mode')
ax[1][1].legend()


sns.kdeplot(df['Humidity3pm'],shade=True,ax = ax[1][2],color = 'green')
ax[1][2].axvline(df['Humidity3pm'].mean(), color='red', label='mean')
ax[1][2].axvline(df['Humidity3pm'].median(), color='green', label='median')
ax[1][2].axvline(df['Humidity3pm'].mode()[0], color='blue', label='mode')
ax[1][2].legend()

sns.kdeplot(df['Temp9am'],shade=True,ax = ax[1][3],color = 'green')
ax[1][3].axvline(df['Temp9am'].mean(), color='red', label='mean')
ax[1][3].axvline(df['Temp9am'].median(), color='green', label='median')
ax[1][3].axvline(df['Temp9am'].mode()[0], color='blue', label='mode')
ax[1][3].legend()
       
    
sns.kdeplot(temp1['Temp3pm'],shade=True,ax = ax[2][0],color = 'green')
ax[2][0].axvline(temp1['Temp3pm'].mean(), color='red', label='mean')
ax[2][0].axvline(temp1['Temp3pm'].median(), color='green', label='median')
ax[2][0].axvline(temp1['Temp3pm'].mode()[0], color='blue', label='mode')
ax[2][0].legend()

sns.kdeplot(df['Evaporation'],shade=True,ax = ax[2][1],color = 'green')
ax[2][1].axvline(df['Evaporation'].mean(), color='red', label='mean')
ax[2][1].axvline(df['Evaporation'].median(), color='green', label='median')
ax[2][1].axvline(df['Evaporation'].mode()[0], color='blue', label='mode')
ax[2][1].legend()

sns.kdeplot(df['Sunshine'],shade=True,ax = ax[2][2],color = 'green')
ax[2][2].axvline(df['Sunshine'].mean(), color='red', label='mean')
ax[2][2].axvline(df['Sunshine'].median(), color='green', label='median')
ax[2][2].axvline(df['Sunshine'].mode()[0], color='blue', label='mode')
ax[2][2].legend()

sns.kdeplot(df['WindGustSpeed'],shade=True,ax = ax[2][2],color = 'green')
ax[2][3].axvline(df['WindGustSpeed'].mean(), color='red', label='mean')
ax[2][3].axvline(df['WindGustSpeed'].median(), color='green', label='median')
ax[2][3].axvline(df['WindGustSpeed'].mode()[0], color='blue', label='mode')
ax[2][3].legend()

sns.kdeplot(df['Pressure9am'],shade=True,ax = ax[3][0],color = 'green')
ax[3][0].axvline(df['Pressure9am'].mean(), color='red', label='mean')
ax[3][0].axvline(df['Pressure9am'].median(), color='green', label='median')
ax[3][0].axvline(df['Pressure9am'].mode()[0], color='blue', label='mode')
ax[3][0].legend()

sns.kdeplot(df['Pressure3pm'],shade=True,ax = ax[3][1],color = 'green')
ax[3][1].axvline(df['Pressure3pm'].mean(), color='red', label='mean')
ax[3][1].axvline(df['Pressure3pm'].median(), color='green', label='median')
ax[3][1].axvline(df['Pressure3pm'].mode()[0], color='blue', label='mode')
ax[3][1].legend()

sns.kdeplot(df['Cloud9am'],shade=True,ax = ax[3][2],color = 'green')
ax[3][2].axvline(df['Cloud9am'].mean(), color='red', label='mean')
ax[3][2].axvline(df['Cloud9am'].median(), color='green', label='median')
ax[3][2].axvline(df['Cloud9am'].mode()[0], color='blue', label='mode')
ax[3][2].legend()

sns.kdeplot(df['Cloud3pm'],shade=True,ax = ax[3][3],color = 'green')
ax[3][3].axvline(df['Cloud3pm'].mean(), color='red', label='mean')
ax[3][3].axvline(df['Cloud3pm'].median(), color='green', label='median')
ax[3][3].axvline(df['Cloud3pm'].mode()[0], color='blue', label='mode')
ax[3][3].legend()

plt.show()

# %% [markdown]
# ![image.png](attachment:726e72b4-203a-4fe7-a38c-a235f802f3f4.png)

# %% [markdown]
# # Data processing

# %%
# Let's first get all the features having percentage of missing values < 5%
cols_1 = [col for col in df.columns if df[col].isnull().mean()*100<5.0 and df[col].isnull().mean()*100>0.0]
temp1 = df[cols_1].copy()
temp1.head(5)
# Out:
#    MinTemp    MaxTemp  Rainfall WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# 0     13.4  22.900000       0.6        WNW          20.0          24.0
# 1      7.4  25.100000       0.0        WSW           4.0          22.0
# 2     12.9  25.700001       0.0        WSW          19.0          26.0
# 3      9.2  28.000000       0.0          E          11.0           9.0
# 4     17.5  32.299999       1.0         NW           7.0          20.0
#
#    Humidity9am  Humidity3pm    Temp9am    Temp3pm RainToday RainTomorrow
# 0         71.0         22.0  16.900000  21.799999        No           No
# 1         44.0         25.0  17.200001  24.299999        No           No
# 2         38.0         30.0  21.000000  23.200001        No           No
# 3         45.0         16.0  18.100000  26.500000        No           No
# 4         82.0         33.0  17.799999  29.700001        No           No

# %%
# Function to find IQR , Upper_lmt and Lower_lmt
def find_upper_and_lower_lmt(series):
    q1 = series.quantile(0.25)
    q3 = series.quantile(0.75)
    IQR = q3-q1
    Upper_lmt = q3 + (1.5*IQR)
    Lower_lmt = q1 - (1.5*IQR)
    return [Upper_lmt,Lower_lmt]

# %%
# Let's cap the outliers
for col in temp1.select_dtypes(include=np.float32).columns:
    lmts = find_upper_and_lower_lmt(temp1[col])
    temp1[col] = np.where(temp1[col] > lmts[0],lmts[0],
    np.where(
        temp1[col] < lmts[1],lmts[1],temp1[col] ))

# %%
# Let's implement CCA technique to handle missing values
# temp1.dropna(inplace=True)

# %%
# Let's visualize the change in the distribution before and after removing the missing values
fig,ax = plt.subplots(3,3,figsize=(18,12))

sns.kdeplot(df['MinTemp'],shade=True,ax = ax[0][0],color = 'red',label = 'Before')
sns.kdeplot(temp1['MinTemp'],shade=True,ax = ax[0][0],color = 'green',label = 'After CCA')
ax[0][0].legend(loc='upper left')

sns.kdeplot(df['MaxTemp'],shade=True,ax = ax[0][1],color = 'red',label = 'Before')
sns.kdeplot(temp1['MaxTemp'],shade=True,ax = ax[0][1],color = 'green',label = 'After CCA')
ax[0][1].legend(loc='upper center')

sns.kdeplot(df['Rainfall'],shade=True,ax = ax[0][2],color = 'red',label = 'Before')
sns.kdeplot(temp1['Rainfall'],shade=True,ax = ax[0][2],color = 'green',label = 'After CCA')
ax[0][2].legend(loc='upper left')

sns.kdeplot(df['WindSpeed9am'],shade=True,ax = ax[1][0],color = 'red',label = 'Before')
sns.kdeplot(temp1['WindSpeed9am'],shade=True,ax = ax[1][0],color = 'green',label = 'After CCA')
ax[1][0].legend(loc='upper center')

sns.kdeplot(df['WindSpeed3pm'],shade=True,ax = ax[1][1],color = 'red',label = 'Before')
sns.kdeplot(temp1['WindSpeed3pm'],shade=True,ax = ax[1][1],color = 'green',label = 'After CCA')
ax[1][1].legend(loc='upper center')

sns.kdeplot(df['Humidity9am'],shade=True,ax = ax[1][2],color = 'red',label = 'Before')
sns.kdeplot(temp1['Humidity9am'],shade=True,ax = ax[1][2],color = 'green',label = 'After CCA')
ax[1][2].legend(loc='upper left')

sns.kdeplot(df['Humidity3pm'],shade=True,ax = ax[2][0],color = 'red',label = 'Before')
sns.kdeplot(temp1['Humidity3pm'],shade=True,ax = ax[2][0],color = 'green',label = 'After CCA')
ax[2][0].legend(loc='upper left')

sns.kdeplot(df['Temp9am'],shade=True,ax = ax[2][1],color = 'red',label = 'Before')
sns.kdeplot(temp1['Temp9am'],shade=True,ax = ax[2][1],color = 'green',label = 'After CCA')
ax[2][1].legend(loc='upper left')

sns.kdeplot(df['Temp3pm'],shade=True,ax = ax[2][2],color = 'red',label = 'Before')
sns.kdeplot(temp1['Temp3pm'],shade=True,ax = ax[2][2],color = 'green',label = 'After CCA')
ax[2][2].legend(loc='upper left')

plt.show()

# %%
# Let's compare the proportion categories in WindDir3pm feature before and after applying Complete case analysis
compare_wd = pd.concat([df['WindDir3pm'].value_counts()/len(df),temp1['WindDir3pm'].value_counts()/len(temp1)],axis=1)
compare_wd.columns = ['Original','After_CCA']
compare_wd
# Out:
#      Original  After_CCA
# SE   0.074508   0.076670
# W    0.069504   0.071380
# S    0.068239   0.069559
# WSW  0.065434   0.067524
# SSE  0.064616   0.066290
# SW   0.064306   0.066639
# N    0.061116   0.062880
# WNW  0.061006   0.062382
# NW   0.059192   0.061045
# ESE  0.058470   0.059915
# E    0.058243   0.059685
# NE   0.056806   0.059432
# SSW  0.056070   0.058169
# NNW  0.054104   0.055940
# ENE  0.054015   0.055866
# NNE  0.045305   0.046623

# %% [markdown]
# Since the distribution of features as well the ratio is not chaning a lot after implementing Complete case analysis, thus it is a green singal to simply drop the missing values

# %%
cols = ['MinTemp', 'MaxTemp', 'Rainfall', 'WindDir3pm', 'WindSpeed9am',
       'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Temp9am', 'Temp3pm',
       'RainToday', 'RainTomorrow']

df.dropna(subset = cols , inplace=True)

# %%
# Now let's do same for WindGustDir and WindGustSpeed feature
temp2 = df[['WindGustDir','WindGustSpeed']].copy()

# %%
# Let's compare the proportion categories in RainToday feature before and after applying Complete case analysis
compare_WindGustDir = pd.concat([df['WindGustDir'].value_counts()/len(df),temp2['WindGustDir'].value_counts()/len(temp2)],axis=1)
compare_WindGustDir.columns = ['Original','After_CCA']
compare_WindGustDir
# Out:
#      Original  After_CCA
# W    0.070577   0.070577
# SE   0.067182   0.067182
# N    0.064864   0.064864
# SSE  0.064789   0.064789
# S    0.064596   0.064596
# E    0.064418   0.064418
# WSW  0.064084   0.064084
# SW   0.063571   0.063571
# SSW  0.062278   0.062278
# WNW  0.057775   0.057775
# NW   0.057530   0.057530
# ENE  0.057099   0.057099
# ESE  0.052017   0.052017
# NE   0.050932   0.050932
# NNW  0.047255   0.047255
# NNE  0.046348   0.046348

# %%
#Let's visualize the change in the distribution before and after removing the missing values
fig,ax = plt.subplots(figsize=(6,4))

sns.kdeplot(df['WindGustSpeed'],shade=True,color = 'red',label = 'Before')
sns.kdeplot(temp2['WindGustSpeed'],shade=True,color = 'green',label = 'After CCA')
ax.legend(loc='upper center')

plt.show()

# %% [markdown]
# Since the distribution and the proportaion of categories is not changing a lot thus it is a green signla that we can remove the missing values

# %%
df.dropna(subset = ['WindGustDir','WindGustSpeed'],inplace=True)

# %%
# Now let's first compile all the features in which the percentage of missing value is more than 5%
cols_2 = [col for col in df.columns if df[col].isnull().mean()*100>5]
temp3 = df[cols_2].copy()
temp3.head(4)
# Out:
#    Evaporation  Sunshine WindDir9am  Pressure9am  Pressure3pm  Cloud9am  \
# 0          NaN       NaN          W  1007.700012  1007.099976       8.0
# 1          NaN       NaN        NNW  1010.599976  1007.799988       NaN
# 2          NaN       NaN          W  1007.599976  1008.700012       NaN
# 3          NaN       NaN         SE  1017.599976  1012.799988       NaN
#
#    Cloud3pm
# 0       NaN
# 1       NaN
# 2       2.0
# 3       NaN

# %% [markdown]
# For imputing the missing values we will use MICE algorithm, but before implementing this algorithm we need to encode the categorical feature

# %%
# Let's encode the Winddir9am feature
map_wind_direction = {'W':0, 'NNW':1, 'SE':2, 'ENE':3, 'SW':4, 'SSE':5, 'S':6, 'NE':7, 'SSW':8, 'N':9, 'WSW':10,'ESE':11,'E':12,'NW':13,
                      'WNW':14, 'NNE':15}

temp3['WindDir9am'] = temp3['WindDir9am'].map(map_wind_direction)

# %%
# Now we will be using MICE for imputing the missing values in company_size variable
lr = LinearRegression()
imp = IterativeImputer(estimator=lr, verbose=2, max_iter=30, tol=1e-10, imputation_order='roman')

# %%
# Let's now impute the missing value
temp3 = imp.fit_transform(temp3)
# Out:
# [IterativeImputer] Completing matrix with shape (128576, 7)
# [IterativeImputer] Ending imputation round 1/30, elapsed time 0.37
# [IterativeImputer] Change: 24.34802982976969, scaled tolerance: 1.041e-07
# [IterativeImputer] Ending imputation round 2/30, elapsed time 0.75
# [IterativeImputer] Change: 6.702993485301235, scaled tolerance: 1.041e-07
# [IterativeImputer] Ending imputation round 3/30, elapsed time 1.12
# [IterativeImputer] Change: 5.181003207896087, scaled tolerance: 1.041e-07
# [IterativeImputer] Ending imputation round 4/30, elapsed time 1.51
# [IterativeImputer] Change: 3.790569472403309, scaled tolerance: 1.041e-07
# [IterativeImputer] Ending imputation round 5/30, elapsed time 1.98
# [IterativeImputer] Change: 2.6524244734741096, scaled tolerance: 1.041e-07
# [IterativeImputer] Ending imputation round 6/30, elapsed time 2.45
# [IterativeImputer] Change: 1.8314511625011711, scaled tolerance: 1.041e-07
# ...

# %%
temp3 = pd.DataFrame(temp3)
temp3.columns = ['Evaporation', 'Sunshine', 'WindDir9am', 'Pressure9am', 'Pressure3pm','Cloud9am', 'Cloud3pm']
temp3 = round(temp3)

# %%
# Now let's convert the WindDir9am feature back to categories
map_wind_direction = {0.0:'W',1.0:'NNW',2.0:'SE', 3.0:'ENE',4.0:'SW',5.0:'SSE', 6.0:'S', 7.0:'NE', 8.0:'SSW',9.0:'N',10.0:'WSW',11.0:'ESE',
                      12.0:'E',13.0:'NW',14.0:'WNW', 15.0:'NNE'}

temp3['WindDir9am'] = temp3['WindDir9am'].map(map_wind_direction)

# %% [markdown]
# After imputing the missing value using MICE let's now check the change in distribution and ratio

# %%
# Let's visualize the change in the distribution before and after removing the missing values
fig,ax = plt.subplots(2,3,figsize=(18,10))

sns.kdeplot(df['Evaporation'],shade=True,ax = ax[0][0],color = 'red',label = 'Before')
sns.kdeplot(temp3['Evaporation'],shade=True,ax = ax[0][0],color = 'green',label = 'After MICE')
ax[0][0].legend(loc='upper left')

sns.kdeplot(df['Sunshine'],shade=True,ax = ax[0][1],color = 'red',label = 'Before')
sns.kdeplot(temp3['Sunshine'],shade=True,ax = ax[0][1],color = 'green',label = 'After MICE')
ax[0][1].legend(loc='upper center')

sns.kdeplot(df['Pressure9am'],shade=True,ax = ax[0][2],color = 'red',label = 'Before')
sns.kdeplot(temp3['Pressure9am'],shade=True,ax = ax[0][2],color = 'green',label = 'After MICE')
ax[0][2].legend(loc='upper left')

sns.kdeplot(df['Pressure3pm'],shade=True,ax = ax[1][0],color = 'red',label = 'Before')
sns.kdeplot(temp3['Pressure3pm'],shade=True,ax = ax[1][0],color = 'green',label = 'After MICE')
ax[1][0].legend(loc='upper center')

sns.kdeplot(df['Cloud9am'],shade=True,ax = ax[1][1],color = 'red',label = 'Before')
sns.kdeplot(temp3['Cloud9am'],shade=True,ax = ax[1][1],color = 'green',label = 'After MICE')
ax[1][1].legend(loc='upper center')

sns.kdeplot(df['Cloud3pm'],shade=True,ax = ax[1][2],color = 'red',label = 'Before')
sns.kdeplot(temp3['Cloud3pm'],shade=True,ax = ax[1][2],color = 'green',label = 'After MICE')
ax[1][2].legend(loc='upper left')

# %%
comopare_wind_dir = pd.concat([df['WindDir9am'].value_counts()/len(df),temp3['WindDir9am'].value_counts()/len(temp3)],axis=1)
comopare_wind_dir.columns = ['Before','After MICE']
comopare_wind_dir
# Out:
#        Before  After MICE
# N    0.082426    0.083064
# SSE  0.066754    0.066754
# E    0.065689    0.065689
# SE   0.064343    0.064343
# S    0.062173    0.062687
# SW   0.058681    0.058681
# NNE  0.058253    0.058253
# W    0.056799    0.056799
# ENE  0.056589    0.056589
# NW   0.056364    0.056364
# NNW  0.056294    0.056294
# ESE  0.054707    0.054707
# SSW  0.054240    0.076818
# NE   0.053291    0.082325
# WNW  0.051145    0.051145
# WSW  0.049473    0.049488

# %%
df.reset_index(inplace=True,drop=True)
temp3.reset_index(inplace=True,drop=True)
temp3.columns = ['evapuration', 'sunshine', 'windDir9am', 'pressure9am', 'pressure3pm','cloud9am', 'cloud3pm']

# %%
df = pd.concat([df,temp3],axis=1)
df.drop(['Evaporation', 'Sunshine', 'WindDir9am', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir3pm', 'WindSpeed9am', 'WindSpeed3pm',
#        'Humidity9am', 'Humidity3pm', 'Temp9am', 'Temp3pm', 'RainToday',
#        'RainTomorrow', 'evapuration', 'sunshine', 'windDir9am', 'pressure9am',
#        'pressure3pm', 'cloud9am', 'cloud3pm'],
#       dtype='object')

# %%
# Let's now check if there are any outliers in the numerical features
fig,ax = plt.subplots(4,4,figsize = (20,15))

sns.kdeplot(df['MinTemp'],shade=True,ax = ax[0][0])
sns.kdeplot(df['MaxTemp'],shade=True,ax = ax[0][1])
sns.kdeplot(df['Rainfall'],shade=True,ax = ax[0][2])
sns.kdeplot(df['WindGustSpeed'],shade=True,ax = ax[0][3])

sns.kdeplot(df['WindSpeed9am'],shade=True,ax = ax[1][0])
sns.kdeplot(df['WindSpeed3pm'],shade=True,ax = ax[1][1])
sns.kdeplot(df['Humidity9am'],shade=True,ax = ax[1][2])
sns.kdeplot(df['Humidity3pm'],shade=True,ax = ax[1][3])

sns.kdeplot(df['Temp9am'],shade=True,ax = ax[2][0])
sns.kdeplot(df['Temp3pm'],shade=True,ax = ax[2][1])
sns.kdeplot(df['evapuration'],shade=True,ax = ax[2][2])
sns.kdeplot(df['sunshine'],shade=True,ax = ax[2][3])

sns.kdeplot(df['pressure9am'],shade=True,ax = ax[3][0])
sns.kdeplot(df['pressure3pm'],shade=True,ax = ax[3][1])
sns.kdeplot(df['cloud9am'],shade=True,ax = ax[3][2])
sns.kdeplot(df['cloud3pm'],shade=True,ax = ax[3][3])
# Out:
# <AxesSubplot:xlabel='cloud3pm', ylabel='Density'>

# %%
temp1 = df.copy()
temp1 = temp1.reset_index()

# %%
# For all the features having sort of normal distribution let's calculate z scores
temp1['MinTemp_z'] = (temp1['MinTemp'] - temp1['MinTemp'].mean())/temp1['MinTemp'].std()
temp1['MaxTemp_z'] = (temp1['MaxTemp'] - temp1['MaxTemp'].mean())/temp1['MaxTemp'].std()
temp1['Humidity3pm_z'] = (temp1['Humidity3pm'] - temp1['Humidity3pm'].mean())/temp1['Humidity3pm'].std()
temp1['Temp9am_z'] = (temp1['Temp9am'] - temp1['Temp9am'].mean())/temp1['Temp9am'].std()
temp1['Temp3pm_z'] = (temp1['Temp3pm'] - temp1['Temp3pm'].mean())/temp1['Temp3pm'].std()
temp1['pressure9am_z'] = (temp1['pressure9am'] - temp1['pressure9am'].mean())/temp1['pressure9am'].std()
temp1['pressure3pm_z'] = (temp1['pressure3pm'] - temp1['pressure3pm'].mean())/temp1['pressure3pm'].std()

# %%
# Let's trim the outliers
temp1 = temp1[(temp1['MinTemp_z'] > -3) | (temp1['MinTemp_z'] < 3)]
temp1 = temp1[(temp1['MaxTemp_z'] > -3) | (temp1['MaxTemp_z'] < 3)]
temp1 = temp1[(temp1['Temp9am_z'] > -3) | (temp1['Temp9am_z'] < 3)]
temp1 = temp1[(temp1['Temp3pm_z'] > -3) | (temp1['Temp3pm_z'] < 3)]
temp1 = temp1[(temp1['pressure9am_z'] > -3) | (temp1['pressure9am_z'] < 3)]
temp1 = temp1[(temp1['pressure3pm_z'] > -3) | (temp1['pressure3pm_z'] < 3)]

# %%
# Let's check the change in distribution before and after trimming outliers
fig,ax = plt.subplots(2,3,figsize = (18,8))

sns.kdeplot(df['MaxTemp'],shade=True,color = 'green',ax = ax[0][0],label='Before')
sns.kdeplot(temp1['MaxTemp'],shade=True,color = 'red',ax = ax[0][0],label = 'After trimming')
ax[0][0].legend(loc='upper left')

sns.kdeplot(df['MinTemp'],shade=True,color = 'green',ax = ax[0][1],label='Before')
sns.kdeplot(temp1['MinTemp'],shade=True,color = 'red',ax = ax[0][1],label = 'After trimming')
ax[0][1].legend(loc='upper left')

sns.kdeplot(df['Temp9am'],shade=True,color = 'green',ax = ax[0][2],label='Before')
sns.kdeplot(temp1['Temp9am'],shade=True,color = 'red',ax = ax[0][2],label = 'After trimming')
ax[0][2].legend(loc='upper left')

sns.kdeplot(df['Temp3pm'],shade=True,color = 'green',ax = ax[1][0],label='Before')
sns.kdeplot(temp1['Temp3pm'],shade=True,color = 'red',ax = ax[1][0],label = 'After trimming')
ax[1][0].legend(loc='upper left')

sns.kdeplot(df['pressure9am'],shade=True,color = 'green',ax = ax[1][1],label='Before')
sns.kdeplot(temp1['pressure9am'],shade=True,color = 'red',ax = ax[1][1],label = 'After trimming')
ax[1][1].legend(loc='upper left')

sns.kdeplot(df['pressure3pm'],shade=True,color = 'green',ax = ax[1][2],label='Before')
sns.kdeplot(temp1['pressure3pm'],shade=True,color = 'red',ax = ax[1][2],label = 'After trimming')
ax[1][2].legend(loc='upper left')

# %%
check = temp1['index'][(temp1['MinTemp_z'] < -3) | (temp1['MinTemp_z'] > 3)]
check
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'MinTemp_z'
#
# ...

# %%
temp1[(temp1['MinTemp_z'] < -3) | (temp1['MinTemp_z'] > 3)]
# Out:
#              Date     Location    MinTemp    MaxTemp  Rainfall WindGustDir  \
# 40432  2014-08-05     Canberra  -7.600000  13.800000       0.2         NNW
# 42321  2011-07-29  Tuggeranong  -8.200000  15.200000       0.0           N
# 44397  2009-06-11  MountGinini  -8.500000   0.600000       1.0           S
# 45626  2014-08-11  MountGinini  -7.500000  -0.700000       0.0           S
# 45984  2015-08-04  MountGinini  -8.200000  -0.800000       0.0         WSW
# 45985  2015-08-05  MountGinini  -7.200000  -1.700000       0.8         WSW
# 46308  2016-06-25  MountGinini  -7.800000  -1.300000       7.4          SW
# 46325  2016-07-13  MountGinini  -7.500000  -4.800000       5.6         WSW
# 46326  2016-07-14  MountGinini  -7.300000   3.200000       1.0          SW
# 63061  2015-12-20      Mildura  31.900000  35.700001       0.0         SSW
# 85768  2009-01-29     Adelaide  33.900002  43.400002       0.0         NNW
# ...
